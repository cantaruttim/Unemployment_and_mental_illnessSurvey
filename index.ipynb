# %%
import pandas as pd
import numpy as np

# %%
# reading documents csv files

df = pd.read_csv('./CSV/CollectorList.csv')
display(df)

mentalIlness = pd.read_csv('./CSV/Mental Illness Survey 1.csv')
display(mentalIlness)
# Out:
#    CollectorID                Title            Date Created
# 0    168522804  Targeted Audience 1  01/14/2018 04:11:00 AM
#      Respondent ID  Collector ID              Start Date  \
# 0              NaN           NaN                     NaN
# 1     6.630447e+09   168522804.0  01/15/2018 03:45:16 AM
# 2     6.630410e+09   168522804.0  01/15/2018 03:17:52 AM
# 3     6.630402e+09   168522804.0  01/15/2018 03:10:28 AM
# 4     6.630335e+09   168522804.0  01/15/2018 02:11:16 AM
# ..             ...           ...                     ...
# 330   6.629053e+09   168522804.0  01/14/2018 03:34:38 AM
# 331   6.629052e+09   168522804.0  01/14/2018 03:34:38 AM
# 332   6.629051e+09   168522804.0  01/14/2018 03:27:20 AM
# 333   6.629051e+09   168522804.0  01/14/2018 03:29:31 AM
# 334   6.629048e+09   168522804.0  01/14/2018 03:24:06 AM
#
#                    End Date  IP Address  Email Address  First Name  Last Name  \
# 0                       NaN         NaN            NaN         NaN        NaN
# ...

# %%
# Cleaning data

mentalIlness = mentalIlness.drop(['IP Address', 'Email Address', 'First Name', 'Last Name'], axis=1) # drop that coluns in Nan

mentalIlness = mentalIlness.rename(columns=df.iloc[0]).loc[1:] # iniciando o df no indice 1

display(mentalIlness)
# Out:
#      Respondent ID  Collector ID              Start Date  \
# 1     6.630447e+09   168522804.0  01/15/2018 03:45:16 AM
# 2     6.630410e+09   168522804.0  01/15/2018 03:17:52 AM
# 3     6.630402e+09   168522804.0  01/15/2018 03:10:28 AM
# 4     6.630335e+09   168522804.0  01/15/2018 02:11:16 AM
# 5     6.630290e+09   168522804.0  01/15/2018 01:24:12 AM
# ..             ...           ...                     ...
# 330   6.629053e+09   168522804.0  01/14/2018 03:34:38 AM
# 331   6.629052e+09   168522804.0  01/14/2018 03:34:38 AM
# 332   6.629051e+09   168522804.0  01/14/2018 03:27:20 AM
# 333   6.629051e+09   168522804.0  01/14/2018 03:29:31 AM
# 334   6.629048e+09   168522804.0  01/14/2018 03:24:06 AM
#
#                    End Date               Custom Data 1  \
# 1    01/15/2018 03:48:24 AM  06f645d7ea5af372d50a62bd17
# 2    01/15/2018 03:18:57 AM  abca2776418ff1fe24bb85e21f
# 3    01/15/2018 03:12:49 AM  3800088cf4e55278b38bbe67f3
# ...

# %%
# Renomeando o nome das colunas 

mentalIlness.rename(columns={"Unnamed: 30": "D1", 
                             "Unnamed: 31": "D2", 
                             "Unnamed: 32": "D3", 
                             "Unnamed: 33": "D3", 
                             "Unnamed: 34": "D4"}, inplace=True)
mentalIlness
# Out:
#      Respondent ID  Collector ID              Start Date  \
# 1     6.630447e+09   168522804.0  01/15/2018 03:45:16 AM
# 2     6.630410e+09   168522804.0  01/15/2018 03:17:52 AM
# 3     6.630402e+09   168522804.0  01/15/2018 03:10:28 AM
# 4     6.630335e+09   168522804.0  01/15/2018 02:11:16 AM
# 5     6.630290e+09   168522804.0  01/15/2018 01:24:12 AM
# ..             ...           ...                     ...
# 330   6.629053e+09   168522804.0  01/14/2018 03:34:38 AM
# 331   6.629052e+09   168522804.0  01/14/2018 03:34:38 AM
# 332   6.629051e+09   168522804.0  01/14/2018 03:27:20 AM
# 333   6.629051e+09   168522804.0  01/14/2018 03:29:31 AM
# 334   6.629048e+09   168522804.0  01/14/2018 03:24:06 AM
#
#                    End Date               Custom Data 1  \
# 1    01/15/2018 03:48:24 AM  06f645d7ea5af372d50a62bd17
# 2    01/15/2018 03:18:57 AM  abca2776418ff1fe24bb85e21f
# 3    01/15/2018 03:12:49 AM  3800088cf4e55278b38bbe67f3
# ...

# %%
mentalIlness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 1 to 334
# Data columns (total 36 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Respondent ID                                                 334 non-null    float64
#  1   Collector ID                                                  334 non-null    float64
#  2   Start Date                                                    334 non-null    object
#  3   End Date                                                      334 non-null    object
#  4   Custom Data 1                                                 334 non-null    object
#  5   I identify as having a mental illness                         334 non-null    object
#  6   Education                                                     334 non-null    object
# ...

# %%
mentalIlness.isnull().sum()
# Out:
# Respondent ID                                                     0
# Collector ID                                                      0
# Start Date                                                        0
# End Date                                                          0
# Custom Data 1                                                     0
# I identify as having a mental illness                             0
# Education                                                         0
# I have my own computer separate from a smart phone                0
# I have been hospitalized before for my mental illness             0
# How many days were you hospitalized for your mental illness      37
# I am currently employed at least part-time                        0
# I am legally disabled                                             0
# I have my regular access to the internet                          0
# I live with my parents                                            0
# ...

# %%
# Observamos a porcentagem de linhas afetadas por valores NaN
mentalIlness.isnull().sum()/mentalIlness.shape[0]*100
# Out:
# Respondent ID                                                    0.000000
# Collector ID                                                     0.000000
# Start Date                                                       0.000000
# End Date                                                         0.000000
# Custom Data 1                                                    0.000000
# I identify as having a mental illness                            0.000000
# Education                                                        0.000000
# I have my own computer separate from a smart phone               0.000000
# I have been hospitalized before for my mental illness            0.000000
# How many days were you hospitalized for your mental illness     11.077844
# I am currently employed at least part-time                       0.000000
# I am legally disabled                                            0.000000
# I have my regular access to the internet                         0.000000
# ...

# %%
import seaborn as sns # dados desbalanceados
sns.countplot(mentalIlness['I identify as having a mental illness']);
# Out:
# C:\Users\Matheus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.histplot(mentalIlness['I identify as having a mental illness']);

# %%
sns.countplot(mentalIlness['How many days were you hospitalized for your mental illness']);
# Out:
# C:\Users\Matheus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(mentalIlness['How many times were you hospitalized for your mental illness']);
# Out:
# C:\Users\Matheus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(mentalIlness['I am unemployed']);
# Out:
# C:\Users\Matheus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(mentalIlness['Education'])
# Out:
# C:\Users\Matheus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.pairplot(data=mentalIlness, hue='Education')

# %%
sns.countplot(mentalIlness['Region'])
# Out:
# C:\Users\Matheus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
sns.countplot(mentalIlness['Gender']);
# Out:
# C:\Users\Matheus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X = mentalIlness.iloc[:, 1:5].values
X.shape
# Out:
# (334, 4)

# %%
y = mentalIlness.iloc[:, 5].values
y.shape
# Out:
# (334,)

# %%
y
# Out:
# array(['No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes',
#        'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No',
#        'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes',
#        'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
# ...
